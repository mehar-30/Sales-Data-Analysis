# %%
import pandas as pd

data = {
    "Date": ["2024-01-01","2024-01-02","2024-01-03","2024-01-04","2024-01-05","2024-01-06"],
    "Product": ["Laptop","Mouse","Keyboard","Laptop","Mouse","Keyboard"],
    "Sales": [1200,25,45,1300,30,50]
}

df = pd.DataFrame(data)

print(df)
# Out:
#          Date   Product  Sales
# 0  2024-01-01    Laptop   1200
# 1  2024-01-02     Mouse     25
# 2  2024-01-03  Keyboard     45
# 3  2024-01-04    Laptop   1300
# 4  2024-01-05     Mouse     30
# 5  2024-01-06  Keyboard     50

# %%
import matplotlib.pyplot as plt

total_sales = df["Sales"].sum()
print("Total Sales:", total_sales)

sales_by_product = df.groupby("Product")["Sales"].sum()
print(sales_by_product)

sales_by_product.plot(kind="bar")

plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")

plt.show()
# Out:
# Total Sales: 2650
# Product
# Keyboard      95
# Laptop      2500
# Mouse         55
# Name: Sales, dtype: int64
